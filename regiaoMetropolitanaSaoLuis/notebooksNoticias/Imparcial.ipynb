# %%
# Importar bibliotecas
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Carregar base com as urls
urls = pd.read_excel('/content/urls.xlsx', sheet_name ='imparcial(RMGSL)')

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

linkMateria = []
tituloMateria = []
corpoMateria = [] 

for url in urls['url']: 
  try:
    req = requests.get(url)
    soup = BeautifulSoup(requests.get(url, headers=headers).content, "html.parser")
   
    link = url
    titulo = soup.find('h1',class_='post-title') 
   
    d = soup.find('div',class_='start-content')
    p = d.find_all('p')
    corpoMateria.append(p)
    
    tituloMateria.append(titulo.text)
    linkMateria.append(link)
 
  except:
    pass

# %%
# Converter para df
df = pd.DataFrame(list(zip(linkMateria,tituloMateria, corpoMateria)), columns=['link','titulo','materia'])
df.head(3)
# Out:
#                                                 link  \
# 0  https://oimparcial.com.br/cidades/2015/07/susp...
# 1  https://oimparcial.com.br/cidades/2015/07/mais...
# 2  https://oimparcial.com.br/cidades/2015/07/duas...
#
#                                               titulo  \
# 0  Suspeito de assalto é espancado por populares ...
# 1  Mais um suspeito de crime é agredido pela popu...
# 2  Duas pessoas foram agredidas por populares na ...
#
#                                              materia
# 0  [[Mais uma demonstração de violência coletiva ...
# 1  [[Mais um suspeito de crime é agredido pela po...
# 2                                                 []

# %%
# Salvar o conteúdo em excel
df.to_excel('imparcial.xlsx')

# %% [markdown]
# # Mineração de Texto

# %%
# Importar bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re
import pandas as pd

# %%
# Baixar módulos
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Ler base
df = pd.read_excel('/content/imparcial.xlsx')

# Remover duplicados
df = df.drop_duplicates(subset=['link'], keep='first')

# %%
# Lista de stopwords customizada
stopWords = []

stopwords_pretext = open('/content/rmgslStopwords.txt', 'r')

with stopwords_pretext as f:
    stopwords_pretext = f.read().splitlines()

stopWords = stopwords_pretext

# %%
# Unir lista customizada com as palavras da NLTK
stopNLTK = stopwords.words('portuguese')
stopWords += stopNLTK

# %% [markdown]
# # Funções

# %%
# Função para remover elementos de html
def parser(text):
    return re.sub('<[^<]+?>', '', str(text))

# Função para limpar os textos do título e do subtítulo
def limparTitulos(df):
  replacer = {'\n':' ',"[\[].*?[\]]": "",'[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para limpar o texto das matérias
def limparMateria(df):
  replacer = {'\n':' ','[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para tokenizar os textos
def tokenizar(df):
  df = df.apply(word_tokenize,language='portuguese') 
  return df  

# Função para contar o número de palavras por texto
def contarPalavras(df):
  lists =  df

  words = []
  for wordList in lists:
    words += wordList
  FreqDist(words)

  # Elencar os x termos mais frequentes
  fdist = FreqDist(words)
  
  # Transforma em df
  termos = pd.DataFrame(list(fdist.items()), columns = ["Termos", "Frequência"]).sort_values(by=['Frequência'], ascending=False)
  
  return termos

# Função para gerar as nuvens de palavras
def gerarNuvem(df):
  df = df.set_index('Termos').to_dict()['Frequência']
  wc = WordCloud(mode = "RGBA", background_color=None,width=800, height=400, max_words=50).generate_from_frequencies(df)

  plt.figure(figsize=(10, 10))
  plt.imshow(wc, interpolation='bilinear')
  plt.axis('off')
  plt.show()
  return plt.show()

# %% [markdown]
# # Pré-processamento

# %%
df['materiaLimpa'] = df.materia.apply(parser)
df['tituloLimpo'] = limparTitulos(df['titulo'])
df['cleanmateriaLimpa'] = limparMateria(df['materiaLimpa'])

# %%
df['tokenizeTitulo'] = tokenizar(df['tituloLimpo'])
df['tokenizeMateria'] = tokenizar(df['cleanmateriaLimpa'])

# %% [markdown]
# # Tokenização e frequências

# %%
frequenciaTitulo = contarPalavras(df['tokenizeTitulo'])
frequenciaTitulo.head(50)
# Out:
#           Termos  Frequência
# 0       suspeito           9
# 1        assalto           7
# 3      populares           5
# 6       agredido           4
# 7      populacao           4
# 21    assaltante           2
# 56         preso           2
# 15     suspeitos           2
# 32      assaltos           2
# 11       crianca           2
# 2      espancado           2
# 22      linchado           2
# 42      praticar           1
# 50         poste           1
# 43         morto           1
# 44        pontal           1
# 45          ilha           1
# 41  antecedentes           1
# 40         lista           1
# 46         dupla           1
# 47      suspeita           1
# 48      linchada           1
# 49      amarrada           1
# 53      cumplice           1
# 51          foge           1
# 52       nadando           1
# 38    justiceiro           1
# 54     feirantes           1
# 55         idoso           1
# 57      estuprar           1
# 58        onibus           1
# 59       areinha           1
# 60         video           1
# 61         homem           1
# 62     atropelar           1
# 63       motoboy           1
# 64         fugir           1
# 39       extensa           1
# 33          leva           1
# 37      baleados           1
# 19       policia           1
# 4         centro           1
# 5          crime           1
# 8        pessoas           1
# 9      agredidas           1
# 10        grande           1
# 12   assassinada           1
# 13          vila           1
# 14      embratel           1
# 16     linchados           1

# %%
frequenciaMateria = contarPalavras(df['tokenizeMateria'])
frequenciaMateria.head(50)
# Out:
#            Termos  Frequência
# 9        suspeito          24
# 42        policia          23
# 20         bairro          17
# 31      populares          16
# 29          homem          15
# 281         roubo          12
# 24         vitima          12
# 65   identificado          11
# 222         local          11
# 272      socorrao          10
# 103      hospital          10
# 15         regiao          10
# 124        cidade           9
# 11       agredido           9
# 61        assalto           9
# 46         acordo           8
# 105       militar           8
# 125      operaria           8
# 58      moradores           8
# 273            ii           8
# 375          arma           8
# 12      populacao           8
# 170      assaltos           6
# 373       plantao           6
# 71          sendo           6
# 5          centro           6
# 137   encaminhado           6
# 10          crime           6
# 50         pessoa           6
# 55      policiais           6
# 126       vitimas           6
# 376          fogo           5
# 277     conduzido           5
# 102        levado           5
# 7         capital           5
# 257    ferimentos           5
# 81         chegou           5
# 335     delegacia           5
# 412         dupla           5
# 122     tentativa           4
# 390       lailson           4
# 48         tentou           4
# 62          noite           4
# 279       autuado           4
# 280     flagrante           4
# 288        medico           4
# 130       pessoas           4
# 14           dias           4
# 165      delegado           4
# 414      informou           4

# %% [markdown]
# # Nuvem de palavras

# %%
gerarNuvem(frequenciaTitulo)

# %%
gerarNuvem(frequenciaMateria)
