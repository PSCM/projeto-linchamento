# %% [markdown]
# # Scraping Notícias

# %%
# Importar bibliotecas
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Carregar base com as urls
urls = pd.read_excel('/content/urls.xlsx', sheet_name ='G1(RMGV)')

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

linkMateria = []
tituloMateria = []
corpoMateria = [] 

for url in urls.url: 
  try:
    req = requests.get(url)
    soup = BeautifulSoup(requests.get(url, headers=headers).content, "html.parser")

    link = url
    if soup.find('h1',itemprop="headline"):
        titulo = soup.find('h1',itemprop="headline")
        
    else:
        titulo = soup.find('h1',class_="entry-title")
    
    tituloMateria.append(titulo.text)
    linkMateria.append(link)

    if soup.find('div', attrs={'class':'mc-article-body'}):
      d = soup.find('div',class_='mc-article-body')
      p = d.find_all('p', class_="content-text__container")
      corpoMateria.append(p)

    else:      
      d = soup.find('div',class_='materia-conteudo entry-content clearfix')
      p = d.find_all('p')
      corpoMateria.append(p)
  
  except:
    pass

# %%
# Converter para df
df = pd.DataFrame(list(zip(linkMateria,tituloMateria, corpoMateria)), columns=['link','titulo','materia'])
df.head(3)
# Out:
#                                                 link  \
# 0  https://g1.globo.com/es/espirito-santo/noticia...
# 1  https://g1.globo.com/es/espirito-santo/noticia...
# 2  https://g1.globo.com/es/espirito-santo/noticia...
#
#                                               titulo  \
# 0  Homem é preso após ser perseguido por guardas ...
# 1  Homem é agredido e preso depois de assaltar ba...
# 2  Suspeitos de assaltos em Vila Velha, ES, são a...
#
#                                              materia
# 0  [[ Um homem que dirigia um carro roubado foi p...
# 1  [[ Um homem de 38 anos foi agredido depois de ...
# 2  [[ Três homens suspeitos de assaltos em Vila V...

# %%
df.to_excel('g1RMGV.xlsx')

# %% [markdown]
# # Mineração de Texto

# %%
# Importar bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re
import pandas as pd

# %%
# Baixar módulos
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Ler base
df = pd.read_excel('/content/g1RMGV.xlsx')

# Remover duplicados
df = df.drop_duplicates(subset=['link'], keep='first')

# %%
# Lista de stopwords customizada
stopWords = []

stopwords_pretext = open('/content/rmgvStopwords.txt', 'r')

with stopwords_pretext as f:
    stopwords_pretext = f.read().splitlines()

stopWords = stopwords_pretext

# %%
# Unir lista customizada com as palavras da NLTK
stopNLTK = stopwords.words('portuguese')
stopWords += stopNLTK

# %% [markdown]
# # Funções

# %%
# Função para remover elementos de html
def parser(text):
    return re.sub('<[^<]+?>', '', str(text))

# Função para limpar os textos do título e do subtítulo
def limparTitulos(df):
  replacer = {'\n':' ',"[\[].*?[\]]": "",'[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para limpar o texto das matérias
def limparMateria(df):
  replacer = {'\n':' ','[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para tokenizar os textos
def tokenizar(df):
  df = df.apply(word_tokenize,language='portuguese') 
  return df  

# Função para contar o número de palavras por texto
def contarPalavras(df):
  lists =  df

  words = []
  for wordList in lists:
    words += wordList
  FreqDist(words)

  # Elencar os x termos mais frequentes
  fdist = FreqDist(words)
  
  # Transforma em df
  termos = pd.DataFrame(list(fdist.items()), columns = ["Termos", "Frequência"]).sort_values(by=['Frequência'], ascending=False)
  
  return termos

# Função para gerar as nuvens de palavras
def gerarNuvem(df):
  df = df.set_index('Termos').to_dict()['Frequência']
  wc = WordCloud(mode = "RGBA", background_color=None,width=800, height=400, max_words=50).generate_from_frequencies(df)

  plt.figure(figsize=(10, 10))
  plt.imshow(wc, interpolation='bilinear')
  plt.axis('off')
  plt.show()
  return plt.show()

# %% [markdown]
# # Pré-processamento

# %%
df['materiaLimpa'] = df.materia.apply(parser)
df['tituloLimpo'] = limparTitulos(df['titulo'])
df['cleanmateriaLimpa'] = limparMateria(df['materiaLimpa'])

# %%
df['tokenizeTitulo'] = tokenizar(df['tituloLimpo'])
df['tokenizeMateria'] = tokenizar(df['cleanmateriaLimpa'])

# %% [markdown]
# # Tokenização e frequências

# %%
frequenciaTitulo = contarPalavras(df['tokenizeTitulo'])
frequenciaTitulo.head(50)
# Out:
#            Termos  Frequência
# 4        agredido          18
# 17      espancado          17
# 12       suspeito          16
# 13        assalto          10
# 0           homem           9
# 1           preso           7
# 6        assaltar           7
# 36         tentar           6
# 10            sao           5
# 34         mulher           5
# 35          jovem           5
# 32         roubar           5
# 46      populares           5
# 71      tentativa           4
# 5       populacao           4
# 65         onibus           4
# 73      moradores           4
# 43        pessoas           4
# 15    adolescente           3
# 62    passageiros           3
# 20          morte           3
# 8       suspeitos           2
# 9        assaltos           2
# 39          carro           2
# 50       pedreiro           2
# 42          grupo           2
# 90        assedio           2
# 61       agredida           2
# 64          tenta           2
# 70       amarrado           2
# 33        celular           2
# 74      estudante           2
# 98    testemunhas           2
# 11      agredidos           2
# 16     esfaqueado           2
# 29   adolescentes           2
# 111      suspeita           1
# 84       amarrada           1
# 83     transexual           1
# 113         baixo           1
# 82          irmas           1
# 81          rouba           1
# 80           ufes           1
# 109    espancados           1
# 112        cabeca           1
# 79         campus           1
# 86          furto           1
# 110      advogado           1
# 78       pizzaria           1
# 77          ponto           1

# %%
frequenciaMateria = contarPalavras(df['tokenizeMateria'])
frequenciaMateria.head(50)
# Out:
#            Termos  Frequência
# 18        policia         121
# 27       suspeito          78
# 0           homem          59
# 53         bairro          52
# 123        vitima          49
# 70        pessoas          46
# 12       agredido          41
# 149         local          40
# 147     moradores          40
# 77         levado          40
# 266   adolescente          37
# 148       militar          34
# 82      delegacia          34
# 116       celular          33
# 188      hospital          32
# 230        onibus          29
# 103        contou          28
# 56            rua          28
# 14         grande          28
# 177         crime          27
# 71         chegou          27
# 108         rapaz          26
# 101        mulher          26
# 451     motorista          26
# 144     bicicleta          23
# 605     populares          23
# 142       assalto          22
# 203          arma          22
# 5           noite          21
# 13      populacao          21
# 91              g          21
# 2           carro          20
# 129          casa          20
# 288         jovem          20
# 97       assaltar          20
# 81    encaminhado          20
# 143        tentou          20
# 95        plantao          19
# 15         acordo          19
# 145    assaltante          18
# 4           preso          18
# 104     criminoso          18
# 223   testemunhas          18
# 341  departamento          17
# 158         roubo          17
# 246     espancado          17
# 141         gente          17
# 94           veja          17
# 270        regiao          17
# 55         entrou          17

# %% [markdown]
# # Nuvem de palavras

# %%
gerarNuvem(frequenciaTitulo)

# %%
gerarNuvem(frequenciaMateria)
