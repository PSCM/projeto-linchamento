# %%
# Importar bibliotecas
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Carregar base com as urls
urls = pd.read_excel('/content/urls.xlsx', sheet_name ='imirante(RMGSL)')

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

linkMateria = []
tituloMateria = []
corpoMateria = [] 

for url in urls['url']: 
  try:
    req = requests.get(url)
    soup = BeautifulSoup(requests.get(url, headers=headers).content, "html.parser")
   
    link = url
    if soup.find('h1',class_='artigo__titulo'): 
      titulo = soup.find('h1',class_='artigo__titulo') 
    else:
      titulo = soup.find('h1',class_='materia-titulo') 
    
    tituloMateria.append(titulo.text)
    linkMateria.append(link)

    if soup.find('div',class_='col-xl-8'):
      d = soup.find('div',class_='col-xl-8')
      p = d.find_all('p')
      corpoMateria.append(p)
    else:
      d = soup.find('div',class_='colunaGrande-6 colunaGrande-offset-3')
      p = d.find_all('p')
      corpoMateria.append(p)

  except:
    pass
# Out:
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
# Converter para df
df = pd.DataFrame(list(zip(linkMateria,tituloMateria, corpoMateria)), columns=['link','titulo','materia'])
df.head(3)
# Out:
#                                                 link  \
# 0  https://imirante.com/noticias/sao-luis/2013/01...
# 1  https://imirante.com/noticias/sao-luis/2013/08...
# 2  https://imirante.com/noticias/sao-luis/2013/10...
#
#                                               titulo  \
# 0      Fim de semana com dois homicídios em São Luís
# 1  Assaltante sofre tentativa de linchamento após...
# 2  Suspeito de roubo é linchado na Matinha, em Sã...
#
#                                              materia
# 0  [[SÃO LUÍS - No fim de semana foram registrado...
# 1  [[SÃO LUÍS - O gerente de uma empresa de cosmé...
# 2  [[SÃO LUÍS – Além do , [jovem “Manoel Neto” qu...

# %%
# Salvar o conteúdo em excel
df.to_excel('imirante.xlsx')

# %% [markdown]
# # Mineração de Texto

# %%
# Importar bibliotecas
import numpy as np
import re
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# %%
# Baixar módulos
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Ler base
df = pd.read_excel('/content/imirante.xlsx')

# Remover duplicados
df = df.drop_duplicates(subset=['link'], keep='first')

# %%
# Lista de stopwords customizada
stopWords = []

stopwords_pretext = open('/content/rmgslStopwords.txt', 'r')

with stopwords_pretext as f:
    stopwords_pretext = f.read().splitlines()

stopWords = stopwords_pretext

# %%
# Unir lista customizada com as palavras da NLTK
stopNLTK = stopwords.words('portuguese')
stopWords += stopNLTK

# %% [markdown]
# # Funções

# %%
# Função para remover elementos de html
def parser(text):
    return re.sub('<[^<]+?>', '', str(text))

# Função para limpar os textos do título e do subtítulo
def limparTitulos(df):
  replacer = {'\n':' ',"[\[].*?[\]]": "",'[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para limpar o texto das matérias
def limparMateria(df):
  replacer = {'\n':' ','[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para tokenizar os textos
def tokenizar(df):
  df = df.apply(word_tokenize,language='portuguese') 
  return df  

# Função para contar o número de palavras por texto
def contarPalavras(df):
  lists =  df

  words = []
  for wordList in lists:
    words += wordList
  FreqDist(words)

  # Elencar os x termos mais frequentes
  fdist = FreqDist(words)
  
  # Transforma em df
  termos = pd.DataFrame(list(fdist.items()), columns = ["Termos", "Frequência"]).sort_values(by=['Frequência'], ascending=False)
  
  return termos

# Função para gerar as nuvens de palavras
def gerarNuvem(df):
  df = df.set_index('Termos').to_dict()['Frequência']
  wc = WordCloud(mode = "RGBA", background_color=None,width=800, height=400, max_words=50).generate_from_frequencies(df)

  plt.figure(figsize=(10, 10))
  plt.imshow(wc, interpolation='bilinear')
  plt.axis('off')
  plt.show()
  return plt.show()

# %% [markdown]
# # Pré-processamento

# %%
df['materiaLimpa'] = df.materia.apply(parser)
df['tituloLimpo'] = limparTitulos(df['titulo'])
df['cleanmateriaLimpa'] = limparMateria(df['materiaLimpa'])

# %%
df['tokenizeTitulo'] = tokenizar(df['tituloLimpo'])
df['tokenizeMateria'] = tokenizar(df['cleanmateriaLimpa'])

# %% [markdown]
# # Tokenização e frequências

# %%
frequenciaTitulo = contarPalavras(df['tokenizeTitulo'])
frequenciaTitulo.head(50)
# Out:
#             Termos  Frequência
# 22         assalto          16
# 5        tentativa          16
# 14       populares          15
# 25           homem          15
# 9         suspeito          11
# 6      linchamento          11
# 11        linchado           7
# 30        agredido           7
# 19       espancado           7
# 3       assaltante           5
# 23         termina           5
# 4            sofre           4
# 69          bairro           4
# 55           preso           4
# 106       assaltar           3
# 34        praticar           3
# 123         onibus           3
# 37          mortes           3
# 104          dupla           3
# 7           roubar           3
# 10           roubo           3
# 75   metropolitana           2
# 64          centro           2
# 91        assaltos           2
# 51           poste           2
# 96       violentas           2
# 58        maracana           2
# 59         suposto           2
# 67           morre           2
# 38     adolescente           2
# 109         fatima           2
# 86          golpes           2
# 80            vila           2
# 1           semana           2
# 79            area           2
# 77        pauladas           2
# 74          regiao           2
# 0              fim           2
# 92           morte           2
# 28           tenta           2
# 33       suspeitos           2
# 2       homicidios           2
# 26          parque           2
# 21          mulher           2
# 20          tentar           2
# 18       forquilha           2
# 31            moto           2
# 32              sl           2
# 13         ribamar           2
# 108          house           1

# %%
frequenciaMateria = contarPalavras(df['tokenizeMateria'])
frequenciaMateria.head(50)
# Out:
#            Termos  Frequência
# 46        policia          63
# 7           homem          46
# 148       assalto          44
# 20      populares          40
# 111        bairro          40
# 132      suspeito          38
# 73         vitima          35
# 56   identificado          33
# 136     tentativa          26
# 149        regiao          25
# 221   linchamento          24
# 301          arma          21
# 77          crime          19
# 54          local          18
# 138     espancado          18
# 355     delegacia          17
# 574      agredido          17
# 151         jovem          17
# 81          morte          17
# 284      hospital          16
# 85      policiais          15
# 167     moradores          15
# 114       pessoas          15
# 428     populacao          15
# 47        militar          15
# 139        levado          15
# 75            rua          14
# 171      socorrao          14
# 168       avenida          14
# 317          vila          14
# 229         noite          13
# 404   adolescente          13
# 165        acordo          13
# 164       ribamar          13
# 97        veiculo          13
# 325         preso          13
# 30          tarde          12
# 21          corpo          12
# 366             h          12
# 11         mulher          12
# 365         volta          12
# 230     suspeitos          12
# 291     seguranca          11
# 18          sendo          11
# 177      policial          11
# 206         manha          10
# 444       chegada          10
# 143    assaltante          10
# 144     conseguiu          10
# 635    registrado          10

# %% [markdown]
# # Nuvem de palavras

# %%
gerarNuvem(frequenciaTitulo)

# %%
gerarNuvem(frequenciaMateria)
