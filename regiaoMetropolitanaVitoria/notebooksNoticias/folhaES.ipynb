# %% [markdown]
# # Scraping Notícias

# %%
# Importar bibliotecas
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Carregar base com as urls
urls = pd.read_excel('/content/urls.xlsx', sheet_name ='folhaES(RMGV)')

# %%
# Scraping das notícias
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

linkMateria = []
tituloMateria = []
corpoMateria = [] 

for url in urls.url: 
  try:

    req = requests.get(url)
    soup = BeautifulSoup(requests.get(url, headers=headers).content, "html.parser")

    link = url
    titulo = soup.find('h2')

    d = soup.find('div', class_='col-12 col-sm-12 col-md-12 col-lg-9 col-xl-9 img100') 
    p = d.find_all('p')
    corpoMateria.append(p) 
    
    linkMateria.append(link)
    tituloMateria.append(titulo.text)

  except:
    pass

# %%
# Converter para df
df = pd.DataFrame(list(zip(linkMateria,tituloMateria, corpoMateria)), columns=['link','titulo','materia'])
df.head(3)
# Out:
#                                                 link  \
# 0  https://www.folhadoes.com/noticia/policia-espi...
# 1  https://www.folhadoes.com/noticia/policia-espi...
# 2  https://www.folhadoes.com/noticia/policia-espi...
#
#                                               titulo  \
# 0  Adolescente morre em pátio de delegacia após s...
# 1  Vizinhos espancam suspeito de estuprar menino ...
# 2  Homem leva uma 'surra' após furtar posto de co...
#
#                                              materia
# 0  [[[<span>O</span>],  adolescente Matheus Ribei...
# 1  [[[<span>V</span>], aldir Paulino da Silva, de...
# 2  [[[<span>N</span>], a tarde desta sexta-feira ...

# %%
# Salvar o conteúdo em excel
df.to_excel('folhaES.xlsx')

# %% [markdown]
# # Mineração de Texto

# %%
# Importar bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re
import pandas as pd

# %%
# Baixar módulos
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Ler base
df = pd.read_excel('/content/folhaES.xlsx')

# Remover duplicados
df = df.drop_duplicates(subset=['link'], keep='first')

# %%
# Lista de stopwords customizada
stopWords = []

stopwords_pretext = open('/content/rmgvStopwords.txt', 'r')

with stopwords_pretext as f:
    stopwords_pretext = f.read().splitlines()

stopWords = stopwords_pretext

# %%
# Unir lista customizada com as palavras da NLTK
stopNLTK = stopwords.words('portuguese')
stopWords += stopNLTK

# %% [markdown]
# # Funções

# %%
# Função para remover elementos de html
def parser(text):
    return re.sub('<[^<]+?>', '', str(text))

# Função para limpar os textos do título e do subtítulo
def limparTitulos(df):
  replacer = {'\n':' ',"[\[].*?[\]]": "",'[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para limpar o texto das matérias
def limparMateria(df):
  replacer = {'\n':' ','[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para tokenizar os textos
def tokenizar(df):
  df = df.apply(word_tokenize,language='portuguese') 
  return df  

# Função para contar o número de palavras por texto
def contarPalavras(df):
  lists =  df

  words = []
  for wordList in lists:
    words += wordList
  FreqDist(words)

  # Elencar os x termos mais frequentes
  fdist = FreqDist(words)
  
  # Transforma em df
  termos = pd.DataFrame(list(fdist.items()), columns = ["Termos", "Frequência"]).sort_values(by=['Frequência'], ascending=False)
  
  return termos

# Função para gerar as nuvens de palavras
def gerarNuvem(df):
  df = df.set_index('Termos').to_dict()['Frequência']
  wc = WordCloud(mode = "RGBA", background_color=None,width=800, height=400, max_words=50).generate_from_frequencies(df)

  plt.figure(figsize=(10, 10))
  plt.imshow(wc, interpolation='bilinear')
  plt.axis('off')
  plt.show()
  return plt.show()

# %% [markdown]
# # Pré-processamento

# %%
df['materiaLimpa'] = df.materia.apply(parser)
df['tituloLimpo'] = limparTitulos(df['titulo'])
df['cleanmateriaLimpa'] = limparMateria(df['materiaLimpa'])

# %%
df['tokenizeTitulo'] = tokenizar(df['tituloLimpo'])
df['tokenizeMateria'] = tokenizar(df['cleanmateriaLimpa'])

# %% [markdown]
# # Tokenização e frequências

# %%
frequenciaTitulo = contarPalavras(df['tokenizeTitulo'])
frequenciaTitulo.head(50)
# Out:
#          Termos  Frequência
# 10        homem           3
# 4     espancado           2
# 0   adolescente           1
# 25    populares           1
# 20       mulher           1
# 21  atravessava           1
# 22        faixa           1
# 23        acaba           1
# 24     linchado           1
# 26   assaltante           1
# 18     atropela           1
# 27         pego           1
# 28      vitimas           1
# 29        preso           1
# 30      acusado           1
# 31     molestar           1
# 19         mata           1
# 16       homens           1
# 17      terreno           1
# 1         morre           1
# 15         gari           1
# 14  combustivel           1
# 13       furtar           1
# 12        surra           1
# 11         leva           1
# 9        menino           1
# 8      estuprar           1
# 7      suspeito           1
# 6      espancam           1
# 5      vizinhos           1
# 3     delegacia           1
# 2         patio           1
# 32      crianca           1

# %%
frequenciaMateria = contarPalavras(df['tokenizeMateria'])
frequenciaMateria.head(50)
# Out:
#            Termos  Frequência
# 5       delegacia          12
# 17        policia          11
# 43      policiais           8
# 73           casa           7
# 177      suspeito           7
# 128        bairro           7
# 289          luan           7
# 189        vitima           7
# 187     moradores           7
# 196       crianca           7
# 18          menor           6
# 154        regiao           5
# 11      espancado           5
# 91          video           5
# 58            mae           5
# 280   restaurante           5
# 104         homem           5
# 24        nolasco           4
# 109        levado           4
# 3          morreu           4
# 299          arma           4
# 338        contou           4
# 155         tarde           4
# 21         acordo           4
# 19         passou           4
# 6        regional           4
# 79          feito           4
# 13        pessoas           4
# 206        chegou           3
# 200         levou           3
# 47       hospital           3
# 117     populares           3
# 284      clientes           3
# 52            fez           3
# 114          veio           3
# 176       chegada           3
# 97   corregedoria           3
# 372      chorando           3
# 180   encaminhado           3
# 182          gari           3
# 262         surra           3
# 98          preso           3
# 102         manha           3
# 64        afirmou           3
# 42       endereco           3
# 25       agredido           3
# 38          crime           3
# 14          praia           3
# 162  identificado           3
# 22       delegado           3

# %% [markdown]
# # Nuvem de palavras

# %%
gerarNuvem(frequenciaTitulo)

# %%
gerarNuvem(frequenciaMateria)
