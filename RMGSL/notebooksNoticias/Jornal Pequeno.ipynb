# %%
# Importar bibliotecas
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Carregar base com as urls
urls = pd.read_excel('/content/urls.xlsx', sheet_name ='jornalPequeno(RMGSL)')

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

linkMateria = []
tituloMateria = []
corpoMateria = [] 

for url in urls['url']: 
  try:
    req = requests.get(url)
    soup = BeautifulSoup(requests.get(url, headers=headers).content, "html.parser")
   
    link = url
    titulo = soup.find('h1',class_='section-title') 
   
    d = soup.find('div',class_='entry-content')
    p = d.find_all('p')
    corpoMateria.append(p)
    
    tituloMateria.append(titulo.text)
    linkMateria.append(link)
 
  except:
    pass

# %%
# Converter para df
df = pd.DataFrame(list(zip(linkMateria,tituloMateria, corpoMateria)), columns=['link','titulo','materia'])
df.head(3)
# Out:
#                                                 link  \
# 0  https://jornalpequeno.blog.br/johncutrim/tres-...
# 1  https://jornalpequeno.blog.br/johncutrim/tres-...
# 2  https://jornalpequeno.blog.br/johncutrim/choqu...
#
#                                               titulo  \
# 0  Três pessoas morrem linchadas em menos de uma ...
# 1  Três pessoas morrem linchadas em menos de uma ...
# 2                                     Choque em ação
#
#                                              materia
# 0  [[[<img alt="morte" class="aligncenter size-me...
# 1  [[[<img alt="morte" class="aligncenter size-me...
# 2  [[[Ten Cel PM Sá, comandante do Choque]], [Açõ...

# %%
# Salvar o conteúdo em excel
df.to_excel('jornalPequeno.xlsx')

# %% [markdown]
# # Mineração de Texto

# %%
# Importar bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re
import pandas as pd

# %%
# Baixar módulos
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Ler base
df = pd.read_excel('/content/jornalPequeno.xlsx')

# Remover duplicados
df = df.drop_duplicates(subset=['link'], keep='first')

# %%
# Lista de stopwords customizada
stopWords = []

stopwords_pretext = open('/content/rmgslStopwords.txt', 'r')

with stopwords_pretext as f:
    stopwords_pretext = f.read().splitlines()

stopWords = stopwords_pretext

# %%
# Unir lista customizada com as palavras da NLTK
stopNLTK = stopwords.words('portuguese')
stopWords += stopNLTK

# %% [markdown]
# # Funções

# %%
# Função para remover elementos de html
def parser(text):
    return re.sub('<[^<]+?>', '', str(text))

# Função para limpar os textos do título e do subtítulo
def limparTitulos(df):
  replacer = {'\n':' ',"[\[].*?[\]]": "",'[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para limpar o texto das matérias
def limparMateria(df):
  replacer = {'\n':' ','[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}
  df = df.replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
  df = df.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8', errors='ignore')
  df = df.apply(lambda x: " ".join(x for x in x.split() if x not in stopWords))
  return df

# Função para tokenizar os textos
def tokenizar(df):
  df = df.apply(word_tokenize,language='portuguese') 
  return df  

# Função para contar o número de palavras por texto
def contarPalavras(df):
  lists =  df

  words = []
  for wordList in lists:
    words += wordList
  FreqDist(words)

  # Elencar os x termos mais frequentes
  fdist = FreqDist(words)
  
  # Transforma em df
  termos = pd.DataFrame(list(fdist.items()), columns = ["Termos", "Frequência"]).sort_values(by=['Frequência'], ascending=False)
  
  return termos

# Função para gerar as nuvens de palavras
def gerarNuvem(df):
  df = df.set_index('Termos').to_dict()['Frequência']
  wc = WordCloud(mode = "RGBA", background_color=None,width=800, height=400, max_words=50).generate_from_frequencies(df)

  plt.figure(figsize=(10, 10))
  plt.imshow(wc, interpolation='bilinear')
  plt.axis('off')
  plt.show()
  return plt.show()

# %% [markdown]
# # Pré-processamento

# %%
df = pd.read_excel('/content/jornalPequeno.xlsx')

# %%
df['materiaLimpa'] = df.materia.apply(parser)
df['tituloLimpo'] = limparTitulos(df['titulo'])
df['cleanmateriaLimpa'] = limparMateria(df['materiaLimpa'])

# %%
df['tokenizeTitulo'] = tokenizar(df['tituloLimpo'])
df['tokenizeMateria'] = tokenizar(df['cleanmateriaLimpa'])

# %% [markdown]
# # Tokenização e frequências

# %%
frequenciaTitulo = contarPalavras(df['tokenizeTitulo'])
frequenciaTitulo.head(50)
# Out:
#           Termos  Frequência
# 0        pessoas           4
# 2      linchadas           4
# 3         semana           4
# 1         morrem           4
# 25    assaltante           3
# 52        cidade           2
# 32     tentativa           2
# 41       assalto           2
# 43      linchado           2
# 15     espancado           2
# 17        mulher           2
# 36     populares           2
# 8            ano           2
# 10  assassinatos           2
# 9           soma           2
# 6     homicidios           2
# 37        roubar           1
# 57         morre           1
# 38   passageiros           1
# 39        onibus           1
# 56          dias           1
# 40      suspeito           1
# 42         preso           1
# 55      registra           1
# 54        grande           1
# 53      operaria           1
# 45     espancada           1
# 46       membros           1
# 47        faccao           1
# 48     criminosa           1
# 49        presos           1
# 35       carcere           1
# 50      suspeita           1
# 51   assassinato           1
# 44         dupla           1
# 29        baleou           1
# 34     condenado           1
# 19         morte           1
# 4         choque           1
# 5           acao           1
# 7        outubro           1
# 11          ilha           1
# 12          veja           1
# 13         video           1
# 14        ladrao           1
# 16       maiobao           1
# 18         livra           1
# 20           dia           1
# 33     homicidio           1
# 21         casos           1

# %%
frequenciaMateria = contarPalavras(df['tokenizeMateria'])
frequenciaMateria.head(50)
# Out:
#            Termos  Frequência
# 4          vitima          30
# 112           dia          21
# 2          pessoa          20
# 3          morreu          20
# 21    linchamento          20
# 249    homicidios          17
# 15         cidade          17
# 23         bairro          16
# 95       conteudo          16
# 76        policia          16
# 256       outubro          15
# 52          marco          15
# 83      populares          15
# 10       agredido          13
# 8        suspeito          13
# 100    reproducao          13
# 258          ilha          12
# 200       ribamar          12
# 196          paco          12
# 65           vila          11
# 329         crime          11
# 250           mes          11
# 197        lumiar          11
# 96           blog          11
# 6       populacao          11
# 18       policial          10
# 91          local          10
# 94      delegacia          10
# 28              h          10
# 263  assassinatos          10
# 539     policiais           9
# 211           ter           9
# 676          foto           9
# 219         sendo           9
# 695       eliezer           9
# 49     maranhense           9
# 48        capital           9
# 129           rua           9
# 102         dados           9
# 271         tiros           8
# 257        grande           8
# 254         morte           8
# 226       acusado           8
# 64          morto           8
# 63     encontrado           8
# 97          livre           8
# 24          cohab           8
# 98       editores           8
# 99      ressalvas           8
# 186        prisao           8

# %% [markdown]
# # Nuvem de palavras

# %%
gerarNuvem(frequenciaTitulo)

# %%
gerarNuvem(frequenciaMateria)
